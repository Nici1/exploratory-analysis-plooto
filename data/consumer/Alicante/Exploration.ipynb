# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
files = [
    "alicante_salinity_EA001_36_level.csv",
    "alicante_salinity_EA002_26_conductivity.csv",
    "alicante_salinity_EA003_36_conductivity.csv",
    "alicante_salinity_EA007_36_conductivity.csv",
    "alicante_salinity_EA008_36_conductivity.csv"
]

# %%
data = pd.read_csv(files[4], names = ['timestamp', 'value'])

level = pd.read_csv(files[0])

#display(data)
#display(level)

# %%
fig, ax = plt.subplots(2, 1, figsize = (15, 5))

ax[0].plot(pd.to_datetime(data['timestamp'], unit = 's'), data['value'])
ax[1].plot(pd.to_datetime(level['timestamp'], unit = 's'), level['value'])



ax[0].set_xlim([datetime.datetime(2022, 2, 13), datetime.datetime(2022, 3, 23)])
ax[1].set_xlim([datetime.datetime(2022, 2, 13), datetime.datetime(2022, 3, 23)])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/tslib.pyx:298, in pandas._libs.tslib.array_with_unit_to_datetime()
#
# ValueError: could not convert string to float: 'timestamp'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/nikola/ML-E3/anomaly-detection/data/consumer/Alicante/Exploration.ipynb Cell 4 line 3
#       <a href='vscode-notebook-cell:/home/nikola/ML-E3/anomaly-detection/data/consumer/Alicante/Exploration.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> fig, ax = plt.subplots(2, 1, figsize = (15, 5))
# ----> <a href='vscode-notebook-cell:/home/nikola/ML-E3/anomaly-detection/data/consumer/Alicante/Exploration.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> ax[0].plot(pd.to_datetime(data['timestamp'], unit = 's'), data['value'])
#       <a href='vscode-notebook-cell:/home/nikola/ML-E3/anomaly-detection/data/consumer/Alicante/Exploration.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> ax[1].plot(pd.to_datetime(level['timestamp'], unit = 's'), level['value'])
#       <a href='vscode-notebook-cell:/home/nikola/ML-E3/anomaly-detection/data/consumer/Alicante/Exploration.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a> ax[0].set_xlim([datetime.datetime(2022, 2, 13), datetime.datetime(2022, 3, 23)])
#
# File ~/anaconda3/envs/anomaly_detection_3/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:805, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     803         result = arg.map(cache_array)
#     804     else:
# --> 805         values = convert_listlike(arg._values, format)
#     806         result = arg._constructor(values, index=arg.index, name=arg.name)
#     807 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~/anaconda3/envs/anomaly_detection_3/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:345, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     342     tz_parsed = None
#     343 else:
# --> 345     result, tz_parsed = tslib.array_with_unit_to_datetime(
#     346         arg, unit, errors=errors
#     347     )
#     349 if errors == "ignore":
#     351     result = Index(result, name=name)
#
# File pandas/_libs/tslib.pyx:301, in pandas._libs.tslib.array_with_unit_to_datetime()
#
# ValueError: non convertible value timestamp with the unit 's'
